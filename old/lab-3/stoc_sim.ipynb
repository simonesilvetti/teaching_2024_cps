# %% [markdown]
# ## StochPy
# ### Stochastic Simulations
#
# This small tutorial is going to show how to use the module **stochpy** and how to mix it with **Moonlight** to do *parameter synthesis*.
#
# We will use the default model, that is "ImmigrationDeath.psc". $\newline$
#
#
# From **stochpy** documentation
# >    We call this the Immigration-death model which we use as the default model in StochPy. Here, we define two reactions: a zero-order reaction R1 synthesizing the species mRNA and a first-order reaction R1 degrading mRNA. Next, we set an initial mRNA copy number and finally the parameter values of the synthesis and degradation rate.
#
# The first reaction is associated with parameter Ksyn, the second one with Kdeg.
# The mRNA initial value is fixed, but it can be changed.
#
# All the stochpy example models are saved in 'C:/Stochpy/pscmodels'.
#
# (Might be different if you are not using Windows. After compiling the cell with the modules, a small description of StochPy will tell you where model folder is.)
#
#
# For more insights on the StochPy module, follow the online documentation:
# -    https://pythonhosted.org/StochPy/modules_doc.html
# -    http://stochpy.sourceforge.net/html/userguide_doc.html

# %%
import numpy as np
import random
import math

from moonlight import *

import stochpy

# Stochpy does some dangerous dir changes, so we restore it after importing.
from os import getcwd, chdir
path = getcwd()
chdir(path)

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12, 10) 
from matplotlib import colors
# Out:
# No module named 'numpy.distutils'
# StochPy requires NumPy
# See http://numpy.scipy.org/ for more information about NumPy
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/git/teaching_2024_cps/env/lib/python3.12/site-packages/stochpy/__init__.py:67
#      66 try:
# ---> 67     from numpy.distutils.core import setup, Extension
#      68     _IsNumPy = True
#
# ModuleNotFoundError: No module named 'numpy.distutils'
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[1], line 7
#       5 from moonlight import *
# ----> 7 import stochpy
#       9 # Stochpy does some dangerous dir changes, so we restore it after importing.
#
# File ~/git/teaching_2024_cps/env/lib/python3.12/site-packages/stochpy/__init__.py:74
#      73     print("See http://numpy.scipy.org/ for more information about NumPy")
# ---> 74     os.sys.exit(-1)
#      76 try:
#
# SystemExit: -1
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/git/teaching_2024_cps/env/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2121, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2118 if exception_only:
#    2119     stb = ['An exception has occurred, use %tb to see '
#    2120            'the full traceback.\n']
# -> 2121     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2122                                                      value))
#    2123 else:
#    2125     def contains_exceptiongroup(val):
#
# File ~/git/teaching_2024_cps/env/lib/python3.12/site-packages/IPython/core/ultratb.py:710, in ListTB.get_exception_only(self, etype, value)
#     702 def get_exception_only(self, etype, value):
#     703     """Only print the exception type and message, without a traceback.
#     704
#     705     Parameters
#    (...)
#     708     value : exception value
#     709     """
# --> 710     return ListTB.structured_traceback(self, etype, value)
#
# File ~/git/teaching_2024_cps/env/lib/python3.12/site-packages/IPython/core/ultratb.py:568, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     565     chained_exc_ids.add(id(exception[1]))
#     566     chained_exceptions_tb_offset = 0
#     567     out_list = (
# --> 568         self.structured_traceback(
#     569             etype,
#     570             evalue,
#     571             (etb, chained_exc_ids),  # type: ignore
#     572             chained_exceptions_tb_offset,
#     573             context,
#     574         )
#     575         + chained_exception_message
#     576         + out_list)
#     578 return out_list
#
# File ~/git/teaching_2024_cps/env/lib/python3.12/site-packages/IPython/core/ultratb.py:1435, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1433 else:
#    1434     self.tb = etb
# -> 1435 return FormattedTB.structured_traceback(
#    1436     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1437 )
#
# File ~/git/teaching_2024_cps/env/lib/python3.12/site-packages/IPython/core/ultratb.py:1326, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1323 mode = self.mode
#    1324 if mode in self.verbose_modes:
#    1325     # Verbose modes need a full traceback
# -> 1326     return VerboseTB.structured_traceback(
#    1327         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1328     )
#    1329 elif mode == 'Minimal':
#    1330     return ListTB.get_exception_only(self, etype, value)
#
# File ~/git/teaching_2024_cps/env/lib/python3.12/site-packages/IPython/core/ultratb.py:1173, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1164 def structured_traceback(
#    1165     self,
#    1166     etype: type,
#    (...)
#    1170     number_of_lines_of_context: int = 5,
#    1171 ):
#    1172     """Return a nice text document describing the traceback."""
# -> 1173     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1174                                                            tb_offset)
#    1176     colors = self.Colors  # just a shorthand + quicker name lookup
#    1177     colorsnormal = colors.Normal  # used a lot
#
# File ~/git/teaching_2024_cps/env/lib/python3.12/site-packages/IPython/core/ultratb.py:1063, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1060 assert isinstance(tb_offset, int)
#    1061 head = self.prepare_header(str(etype), self.long_header)
#    1062 records = (
# -> 1063     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1064 )
#    1066 frames = []
#    1067 skipped = 0
#
# File ~/git/teaching_2024_cps/env/lib/python3.12/site-packages/IPython/core/ultratb.py:1131, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1129 while cf is not None:
#    1130     try:
# -> 1131         mod = inspect.getmodule(cf.tb_frame)
#    1132         if mod is not None:
#    1133             mod_name = mod.__name__
#
# AttributeError: 'tuple' object has no attribute 'tb_frame'

# %% [markdown]
# The following functions simulate the Immigration-Death model from the StochPy module.
#
# It is prepare to run using default parameters.
# Some details will be printed directly by the function *StochasticModellingWithParameters()*.
#
# If you want to inspect the functions, they have a bit of documentation.
# -    ImmigrationDeathSSA(Ksyn, Kdeg, ltime, n_samples): it simulates one time the model using the parameters in input. It return the SSA, so it can be inspected indipendently as stochpy object;
#
# -    getSpeciesTimeSeriesAsArray(ssa): using some inner stochpy notation, it is possible to extract the trajectories from the simulation. It takes in input the SSA object and returns an multi-dimensional array, where the first position refers to the trajectory, the others are the time steps and the value;
#
# -    StochModel(n_traj, ltime, Ksyn, Kdeg): one run of this function will simulate a set of *n_traj* trajectories for the couple of parameters in input, each of length *ltime*. It return a couple of values: they are the average robustness for the two formulas used for the monitoring;
#
# -    StochasticModellingWithParameters(ltime, n_traj, parameterKsyn, parameterKdeg, model): this function repeats the simulation for all the possible couple of parameters $(Ksyn, Kdeg) \in \text{parametersKsyn} \times \text{parametersKdeg}$.
#
# They take parameter in input such as the length of the time interval, the number of trajectories for each run, the parameters, ..
# This is already set up by default to have nice results, but inspecting the code you can change a lot of details, like the set of parameters, the formulas, the time interval, ...
#
# The default function takes a half a minute to execute.

# %%
def ImmigrationDeathSSA(Ksyn, Kdeg, ltime, n_samples):
     """
     stochpy.SSA() call the stochastic simulation algorithm for the model in input, 
          the default is model_file = "ImmigrationDeath.psc".
     ssa.ChangeParameter() does exactly what it seems, takes as first argument 
          the name of the parameter between quotation marks and as second argument the new value.
     ssa.DoStochSim() simulate one run of the model. The parameter trajectories can be added
          to have more simulation on the same object.
     ssa.GetRegularGrid() divides the time interval in n_samples time step of the same length. 
          The value associate to each step i is the average of the points in the interval [i, i+1]
          This is useful since the waiting time for the reactions is different at each step.
     """

     ssa = stochpy.SSA()
     ssa.ChangeParameter("Ksyn", Ksyn)
     ssa.ChangeParameter("Kdeg", Kdeg)
     ssa.DoStochSim(end = ltime, mode = 'steps')
     ssa.GetRegularGrid(n_samples = n_samples)

     return ssa

def getSpeciesTimeSeriesAsArray(ssa):
     """
     This function extract the data of the simulation trajectory(ies).
     Since time step of each reaction is different, this function is adapted to our case.
     Time steps are of fixed length of dimension 0.1.

     The following is stochpy inner code, I suggest to check directly the documentation of
          stochpy or the "real" code (or you can trust me).
     """
     assert ssa._IsSimulationDone, "First do a stochastic simulation"  
     values = np.ndarray((ssa.sim_trajectories_done, len(ssa.data_stochsim.getSpecies()), 2))
     for n in range(1,ssa.sim_trajectories_done+1):
          if ssa.sim_trajectories_done > 1:
               ssa.GetTrajectoryData(n)

          count = 0
          for timepoint in ssa.data_stochsim.getSpecies():
               for value in range(len(timepoint)):
                    values[n-1][count][0] = round(count/10, ndigits = 1)
                    values[n-1][count][1] = timepoint[1]
               count += 1
     return values

############################################################################################


def StochModel(     n_traj = 8, 
                    ltime = 800,   
                    Ksyn = 18, 
                    Kdeg = 0.15    ):
     """
     This function reproduce the stochastic model for a single couple of parameter.
     The parameters are set up by default, so that it can be run indipendently.

     The output of the function getSpeciesTimeSeries() is a np.ndarray where the first dimension refers
          to the trajectory, the others two to the time steps and its values.     
     
     The script is fixed, but it is easy to add it as input parameter with a simple if condition
          def StochModel(..., script = False):
               ...
               if not script:
                    script =  "..
                              ...
                              .."
     
     What happens next is the Moonlight monitoring for each trajectory.

     The output is a couple: the average robustness over the set of trajectories for a single 
          couple of parameters with respect to the two formulas phi1 and phi2 in the script. 
     """

     Ksyn = float(Ksyn)
     Kdeg = float(Kdeg)
     
     n_samples = 10*ltime + 1 
     robustness1 = list()
     robustness2 = list()

     for traj in range(n_traj):
          
          ssa = ImmigrationDeathSSA(Ksyn, Kdeg, ltime, n_samples)
          v = getSpeciesTimeSeriesAsArray(ssa)

          script = """
          signal { real values;   }
          domain minmax; 
          formula phi1 = globally [20, 79.9] ( (values > 100) & (values < 140)  ) ;
          formula phi2 = globally [20, 79.9] ( eventually [0, 1] ( (values > 100) & (values < 140 ) )) ;
          """

          moonlightScript = ScriptLoader.loadFromText(script)
          monitor1 = moonlightScript.getMonitor("phi1")
          monitor2 = moonlightScript.getMonitor("phi2")


          ## Prepare the data for monitoring
          timeSignalValues = v[0].transpose()[0].tolist()

          signal = list()
          for i in range(len(timeSignalValues)):
               signal.append([v[0].transpose()[1].tolist()[i]])


          result1 = np.array(monitor1.monitor(timeSignalValues, signal))
          result2 = np.array(monitor2.monitor(timeSignalValues, signal))

          ## Uncomment the following two lines if you want to see the results of a single simulation.
          ## If you leave them during the full computation, it will print a bit to much, so remember to recomment them.
          print("Formula phi1:\t", result1.transpose()[1], ", \tmax: ", max(v.transpose()[1][100:]), ",\t min: ", min(v.transpose()[1][100:]))
          print("Formula phi2:\t", result2.transpose()[1], ", \tmax: ", max(v.transpose()[1][100:]), ",\t min: ", min(v.transpose()[1][100:]), "\n")

          robustness1.append(result1.transpose()[1])
          robustness2.append(result2.transpose()[1])
     
     return np.mean(robustness1), np.mean(robustness2) 


######################################################################################################


def StochasticModellingWithParameters(  ltime = 800,
                                        n_traj = 8, 
                                        parameterKsyn = np.arange(16, 21, 1),
                                        parameterKdeg = np.arange(0.13, 0.18, 0.01),
                                        model = "ImmigrationDeath.psc"    ):
     """
     This function repeat the stochastic simulation over a set of parameters.
     It is prepared to run with default parameters.

     The robustness for the two formulas is saved in two matrices and it is printed
          using plt.imshow(). Darker greens mean a higher value of robustness, so it is
          easy to see for which parameters we have the best value.
          The couple of parameter refering to the maximum value is also printed after the plot.
     """

     lSyn = len(parameterKsyn)
     lDeg = len(parameterKdeg)

     robustnessResults1 = np.ndarray((lSyn, lDeg))
     robustnessResults2 = np.ndarray((lSyn, lDeg))

     print("The number of time steps is ", ltime)
     print("The number of trajectories for each simulation is ", n_traj)
     print()

     print("\nInterval extremes for Ksyn: \t[ ", parameterKsyn[0], ",\t", parameterKsyn[-1], "]")
     print("The interval has ", lSyn, " steps, each of length ", round((parameterKsyn[-1]-parameterKsyn[0])/(lSyn-1), ndigits = 2))

     print("\nInterval extremes for Kdeg: \t[ ", parameterKdeg[0], ",\t", round(parameterKdeg[-1], ndigits = 3), "]")
     print("The interval has ", lDeg, " steps, each of length ", round((parameterKdeg[-1]-parameterKdeg[0])/(lDeg-1), ndigits = 4))
     print()

     print("The formulas are:")
     print("-\tphi1 = globally [20, 79.9] ( (values > 100) & (values < 140)  ) ;")
     print("-\tphi2 = globally [20, 79.9] ( eventually [0, 1] ( (values > 100) & (values < 140 ) ))")

     for syn in range(lSyn):
          for deg in range(lDeg):
               robustnessResults1[syn][deg], robustnessResults2[syn][deg] = StochModel(Ksyn = parameterKsyn[syn], Kdeg = parameterKdeg[deg])[:]

     # Make the plots
     R1indices = [robustnessResults1.max(), robustnessResults1.argmax() // lSyn, robustnessResults1.argmax() % lDeg]
     R2indices = [robustnessResults2.max(), robustnessResults2.argmax() // lSyn, robustnessResults2.argmax() % lDeg]

     plt.imshow(robustnessResults1, interpolation ='nearest', 
                    extent =[0, lSyn, 0, lDeg],
                    cmap = 'Greens')

     plt.colorbar()
     plt.show()
     print("The maximum value is ", R1indices[0], " for the couple [", parameterKsyn[R1indices[1]], ", ", round(parameterKdeg[R1indices[2]], ndigits = 3), "]\n")

     plt.imshow(robustnessResults2, interpolation ='nearest', 
                    extent =[0, lSyn, 0, lDeg],
                    cmap = 'Greens')

     plt.colorbar()
     plt.show()
     print("The maximum value is ", R2indices[0], " for the couple [", parameterKsyn[R2indices[1]], ", ", round(parameterKdeg[R2indices[2]], ndigits = 3), "]\n")

# %%
StochasticModellingWithParameters()
# Out:
# The number of time steps is  800
# The number of trajectories for each simulation is  8
#
#
# Interval extremes for Ksyn: 	[  16 ,	 20 ]
# The interval has  5  steps, each of length  1.0
#
# Interval extremes for Kdeg: 	[  0.13 ,	 0.17 ]
# The interval has  5  steps, each of length  0.01
#
# The formulas are:
# -	phi1 = globally [20, 79.9] ( (values > 100) & (values < 140)  ) ;
# -	phi2 = globally [20, 79.9] ( eventually [0, 1] ( (values > 100) & (values < 140 ) ))
# Formula phi1:	 [-5.] , 	max:  [120.] ,	 min:  [76.]
# Formula phi2:	 [-2.] , 	max:  [120.] ,	 min:  [76.]
#
# Formula phi1:	 [-8.] , 	max:  [128.] ,	 min:  [76.]
# Formula phi2:	 [-6.] , 	max:  [128.] ,	 min:  [76.]
#
# Formula phi1:	 [-6.] , 	max:  [140.] ,	 min:  [80.]
# Formula phi2:	 [-3.] , 	max:  [140.] ,	 min:  [80.]
#
# Formula phi1:	 [-16.] , 	max:  [128.] ,	 min:  [80.]
# Formula phi2:	 [-10.] , 	max:  [128.] ,	 min:  [80.]
#
# Formula phi1:	 [-16.] , 	max:  [137.] ,	 min:  [76.]
# Formula phi2:	 [-13.] , 	max:  [137.] ,	 min:  [76.]
#
# Formula phi1:	 [-1.] , 	max:  [128.] ,	 min:  [81.]
# Formula phi2:	 [2.] , 	max:  [128.] ,	 min:  [81.]
#
# Formula phi1:	 [-2.] , 	max:  [129.] ,	 min:  [87.]
# Formula phi2:	 [1.] , 	max:  [129.] ,	 min:  [87.]
#
# Formula phi1:	 [-13.] , 	max:  [120.] ,	 min:  [80.]
# Formula phi2:	 [-10.] , 	max:  [120.] ,	 min:  [80.]
#
# Formula phi1:	 [-7.] , 	max:  [123.] ,	 min:  [80.]
# Formula phi2:	 [-3.] , 	max:  [123.] ,	 min:  [80.]
#
# Formula phi1:	 [-17.] , 	max:  [124.] ,	 min:  [73.]
# Formula phi2:	 [-14.] , 	max:  [124.] ,	 min:  [73.]
#
# Formula phi1:	 [-6.] , 	max:  [117.] ,	 min:  [83.]
# Formula phi2:	 [-2.] , 	max:  [117.] ,	 min:  [83.]
#
# Formula phi1:	 [-4.] , 	max:  [117.] ,	 min:  [83.]
# Formula phi2:	 [-2.] , 	max:  [117.] ,	 min:  [83.]
#
# Formula phi1:	 [-2.] , 	max:  [121.] ,	 min:  [73.]
# Formula phi2:	 [2.] , 	max:  [121.] ,	 min:  [73.]
#
# Formula phi1:	 [-9.] , 	max:  [127.] ,	 min:  [72.]
# Formula phi2:	 [-6.] , 	max:  [127.] ,	 min:  [72.]
#
# Formula phi1:	 [-4.] , 	max:  [123.] ,	 min:  [85.]
# Formula phi2:	 [-1.] , 	max:  [123.] ,	 min:  [85.]
#
# Formula phi1:	 [0.] , 	max:  [127.] ,	 min:  [82.]
# Formula phi2:	 [3.] , 	max:  [127.] ,	 min:  [82.]
#
# Formula phi1:	 [-27.] , 	max:  [104.] ,	 min:  [70.]
# Formula phi2:	 [-22.] , 	max:  [104.] ,	 min:  [70.]
#
# Formula phi1:	 [-4.] , 	max:  [134.] ,	 min:  [84.]
# Formula phi2:	 [1.] , 	max:  [134.] ,	 min:  [84.]
#
# Formula phi1:	 [-21.] , 	max:  [108.] ,	 min:  [65.]
# Formula phi2:	 [-18.] , 	max:  [108.] ,	 min:  [65.]
#
# Formula phi1:	 [-25.] , 	max:  [112.] ,	 min:  [75.]
# Formula phi2:	 [-22.] , 	max:  [112.] ,	 min:  [75.]
#
# Formula phi1:	 [-11.] , 	max:  [109.] ,	 min:  [84.]
# Formula phi2:	 [-7.] , 	max:  [109.] ,	 min:  [84.]
#
# Formula phi1:	 [-14.] , 	max:  [118.] ,	 min:  [76.]
# Formula phi2:	 [-11.] , 	max:  [118.] ,	 min:  [76.]
#
# Formula phi1:	 [-10.] , 	max:  [117.] ,	 min:  [84.]
# Formula phi2:	 [-7.] , 	max:  [117.] ,	 min:  [84.]
#
# Formula phi1:	 [-19.] , 	max:  [118.] ,	 min:  [60.]
# Formula phi2:	 [-14.] , 	max:  [118.] ,	 min:  [60.]
#
# Formula phi1:	 [-27.] , 	max:  [112.] ,	 min:  [71.]
# Formula phi2:	 [-24.] , 	max:  [112.] ,	 min:  [71.]
#
# Formula phi1:	 [-26.] , 	max:  [104.] ,	 min:  [62.]
# Formula phi2:	 [-23.] , 	max:  [104.] ,	 min:  [62.]
#
# Formula phi1:	 [-14.] , 	max:  [111.] ,	 min:  [75.]
# Formula phi2:	 [-12.] , 	max:  [111.] ,	 min:  [75.]
#
# Formula phi1:	 [-7.] , 	max:  [114.] ,	 min:  [75.]
# Formula phi2:	 [-4.] , 	max:  [114.] ,	 min:  [75.]
#
# Formula phi1:	 [-9.] , 	max:  [117.] ,	 min:  [80.]
# Formula phi2:	 [-6.] , 	max:  [117.] ,	 min:  [80.]
#
# Formula phi1:	 [-36.] , 	max:  [102.] ,	 min:  [64.]
# Formula phi2:	 [-33.] , 	max:  [102.] ,	 min:  [64.]
#
# Formula phi1:	 [-16.] , 	max:  [108.] ,	 min:  [71.]
# Formula phi2:	 [-11.] , 	max:  [108.] ,	 min:  [71.]
#
# Formula phi1:	 [-21.] , 	max:  [107.] ,	 min:  [66.]
# Formula phi2:	 [-18.] , 	max:  [107.] ,	 min:  [66.]
#
# Formula phi1:	 [-15.] , 	max:  [111.] ,	 min:  [74.]
# Formula phi2:	 [-11.] , 	max:  [111.] ,	 min:  [74.]
#
# Formula phi1:	 [-30.] , 	max:  [93.] ,	 min:  [66.]
# Formula phi2:	 [-28.] , 	max:  [93.] ,	 min:  [66.]
#
# Formula phi1:	 [-25.] , 	max:  [106.] ,	 min:  [75.]
# Formula phi2:	 [-22.] , 	max:  [106.] ,	 min:  [75.]
#
# Formula phi1:	 [-19.] , 	max:  [104.] ,	 min:  [67.]
# Formula phi2:	 [-16.] , 	max:  [104.] ,	 min:  [67.]
#
# Formula phi1:	 [-25.] , 	max:  [103.] ,	 min:  [72.]
# Formula phi2:	 [-21.] , 	max:  [103.] ,	 min:  [72.]
#
# Formula phi1:	 [-23.] , 	max:  [105.] ,	 min:  [77.]
# Formula phi2:	 [-20.] , 	max:  [105.] ,	 min:  [77.]
#
# Formula phi1:	 [-23.] , 	max:  [101.] ,	 min:  [66.]
# Formula phi2:	 [-19.] , 	max:  [101.] ,	 min:  [66.]
#
# Formula phi1:	 [-30.] , 	max:  [94.] ,	 min:  [62.]
# Formula phi2:	 [-26.] , 	max:  [94.] ,	 min:  [62.]
#
# Formula phi1:	 [-14.] , 	max:  [137.] ,	 min:  [66.]
# Formula phi2:	 [-11.] , 	max:  [137.] ,	 min:  [66.]
#
# Formula phi1:	 [-11.] , 	max:  [151.] ,	 min:  [85.]
# Formula phi2:	 [-8.] , 	max:  [151.] ,	 min:  [85.]
#
# Formula phi1:	 [-15.] , 	max:  [137.] ,	 min:  [67.]
# Formula phi2:	 [-13.] , 	max:  [137.] ,	 min:  [67.]
#
# Formula phi1:	 [1.] , 	max:  [126.] ,	 min:  [78.]
# Formula phi2:	 [5.] , 	max:  [126.] ,	 min:  [78.]
#
# Formula phi1:	 [-15.] , 	max:  [133.] ,	 min:  [80.]
# Formula phi2:	 [-13.] , 	max:  [133.] ,	 min:  [80.]
#
# Formula phi1:	 [-10.] , 	max:  [147.] ,	 min:  [67.]
# Formula phi2:	 [-6.] , 	max:  [147.] ,	 min:  [67.]
#
# Formula phi1:	 [-12.] , 	max:  [136.] ,	 min:  [76.]
# Formula phi2:	 [-6.] , 	max:  [136.] ,	 min:  [76.]
#
# Formula phi1:	 [-6.] , 	max:  [145.] ,	 min:  [78.]
# Formula phi2:	 [-2.] , 	max:  [145.] ,	 min:  [78.]
#
# Formula phi1:	 [-12.] , 	max:  [127.] ,	 min:  [75.]
# Formula phi2:	 [-7.] , 	max:  [127.] ,	 min:  [75.]
#
# Formula phi1:	 [-8.] , 	max:  [139.] ,	 min:  [76.]
# Formula phi2:	 [-5.] , 	max:  [139.] ,	 min:  [76.]
#
# Formula phi1:	 [-4.] , 	max:  [123.] ,	 min:  [78.]
# Formula phi2:	 [0.] , 	max:  [123.] ,	 min:  [78.]
#
# Formula phi1:	 [-11.] , 	max:  [125.] ,	 min:  [78.]
# Formula phi2:	 [-8.] , 	max:  [125.] ,	 min:  [78.]
#
# Formula phi1:	 [-14.] , 	max:  [124.] ,	 min:  [76.]
# Formula phi2:	 [-12.] , 	max:  [124.] ,	 min:  [76.]
#
# Formula phi1:	 [-4.] , 	max:  [123.] ,	 min:  [73.]
# Formula phi2:	 [0.] , 	max:  [123.] ,	 min:  [73.]
#
# Formula phi1:	 [-9.] , 	max:  [140.] ,	 min:  [77.]
# Formula phi2:	 [-6.] , 	max:  [140.] ,	 min:  [77.]
#
# Formula phi1:	 [-7.] , 	max:  [119.] ,	 min:  [81.]
# Formula phi2:	 [-3.] , 	max:  [119.] ,	 min:  [81.]
#
# Formula phi1:	 [-13.] , 	max:  [137.] ,	 min:  [64.]
# Formula phi2:	 [-11.] , 	max:  [137.] ,	 min:  [64.]
#
# Formula phi1:	 [-17.] , 	max:  [128.] ,	 min:  [71.]
# Formula phi2:	 [-14.] , 	max:  [128.] ,	 min:  [71.]
#
# Formula phi1:	 [-12.] , 	max:  [109.] ,	 min:  [74.]
# Formula phi2:	 [-9.] , 	max:  [109.] ,	 min:  [74.]
#
# Formula phi1:	 [-9.] , 	max:  [120.] ,	 min:  [65.]
# Formula phi2:	 [-7.] , 	max:  [120.] ,	 min:  [65.]
#
# Formula phi1:	 [-6.] , 	max:  [125.] ,	 min:  [90.]
# Formula phi2:	 [-2.] , 	max:  [125.] ,	 min:  [90.]
#
# Formula phi1:	 [2.] , 	max:  [122.] ,	 min:  [78.]
# Formula phi2:	 [4.] , 	max:  [122.] ,	 min:  [78.]
#
# Formula phi1:	 [-12.] , 	max:  [122.] ,	 min:  [72.]
# Formula phi2:	 [-9.] , 	max:  [122.] ,	 min:  [72.]
#
# Formula phi1:	 [-22.] , 	max:  [113.] ,	 min:  [76.]
# Formula phi2:	 [-19.] , 	max:  [113.] ,	 min:  [76.]
#
# Formula phi1:	 [-9.] , 	max:  [116.] ,	 min:  [82.]
# Formula phi2:	 [-6.] , 	max:  [116.] ,	 min:  [82.]
#
# Formula phi1:	 [-18.] , 	max:  [112.] ,	 min:  [75.]
# Formula phi2:	 [-15.] , 	max:  [112.] ,	 min:  [75.]
#
# Formula phi1:	 [-10.] , 	max:  [117.] ,	 min:  [82.]
# Formula phi2:	 [-8.] , 	max:  [117.] ,	 min:  [82.]
#
# Formula phi1:	 [-10.] , 	max:  [127.] ,	 min:  [80.]
# Formula phi2:	 [-8.] , 	max:  [127.] ,	 min:  [80.]
#
# Formula phi1:	 [-19.] , 	max:  [133.] ,	 min:  [70.]
# Formula phi2:	 [-17.] , 	max:  [133.] ,	 min:  [70.]
#
# Formula phi1:	 [-21.] , 	max:  [121.] ,	 min:  [77.]
# Formula phi2:	 [-18.] , 	max:  [121.] ,	 min:  [77.]
#
# Formula phi1:	 [-22.] , 	max:  [117.] ,	 min:  [78.]
# Formula phi2:	 [-19.] , 	max:  [117.] ,	 min:  [78.]
#
# Formula phi1:	 [-24.] , 	max:  [109.] ,	 min:  [74.]
# Formula phi2:	 [-21.] , 	max:  [109.] ,	 min:  [74.]
#
# Formula phi1:	 [-36.] , 	max:  [114.] ,	 min:  [60.]
# Formula phi2:	 [-34.] , 	max:  [114.] ,	 min:  [60.]
#
# Formula phi1:	 [-22.] , 	max:  [101.] ,	 min:  [69.]
# Formula phi2:	 [-20.] , 	max:  [101.] ,	 min:  [69.]
#
# Formula phi1:	 [-20.] , 	max:  [123.] ,	 min:  [67.]
# Formula phi2:	 [-17.] , 	max:  [123.] ,	 min:  [67.]
#
# Formula phi1:	 [-29.] , 	max:  [123.] ,	 min:  [71.]
# Formula phi2:	 [-27.] , 	max:  [123.] ,	 min:  [71.]
#
# Formula phi1:	 [-23.] , 	max:  [109.] ,	 min:  [67.]
# Formula phi2:	 [-19.] , 	max:  [109.] ,	 min:  [67.]
#
# Formula phi1:	 [-18.] , 	max:  [119.] ,	 min:  [71.]
# Formula phi2:	 [-14.] , 	max:  [119.] ,	 min:  [71.]
#
# Formula phi1:	 [-19.] , 	max:  [113.] ,	 min:  [73.]
# Formula phi2:	 [-14.] , 	max:  [113.] ,	 min:  [73.]
#
# Formula phi1:	 [-23.] , 	max:  [114.] ,	 min:  [75.]
# Formula phi2:	 [-20.] , 	max:  [114.] ,	 min:  [75.]
#
# Formula phi1:	 [-5.] , 	max:  [145.] ,	 min:  [84.]
# Formula phi2:	 [-3.] , 	max:  [145.] ,	 min:  [84.]
#
# Formula phi1:	 [5.] , 	max:  [135.] ,	 min:  [96.]
# Formula phi2:	 [7.] , 	max:  [135.] ,	 min:  [96.]
#
# Formula phi1:	 [-2.] , 	max:  [133.] ,	 min:  [78.]
# Formula phi2:	 [4.] , 	max:  [133.] ,	 min:  [78.]
#
# Formula phi1:	 [1.] , 	max:  [139.] ,	 min:  [80.]
# Formula phi2:	 [3.] , 	max:  [139.] ,	 min:  [80.]
#
# Formula phi1:	 [-3.] , 	max:  [143.] ,	 min:  [76.]
# Formula phi2:	 [1.] , 	max:  [143.] ,	 min:  [76.]
#
# Formula phi1:	 [-8.] , 	max:  [148.] ,	 min:  [83.]
# Formula phi2:	 [-2.] , 	max:  [148.] ,	 min:  [83.]
#
# Formula phi1:	 [-9.] , 	max:  [139.] ,	 min:  [90.]
# Formula phi2:	 [-7.] , 	max:  [139.] ,	 min:  [90.]
#
# Formula phi1:	 [-7.] , 	max:  [134.] ,	 min:  [85.]
# Formula phi2:	 [-4.] , 	max:  [134.] ,	 min:  [85.]
#
# Formula phi1:	 [-3.] , 	max:  [140.] ,	 min:  [72.]
# Formula phi2:	 [1.] , 	max:  [140.] ,	 min:  [72.]
#
# Formula phi1:	 [-5.] , 	max:  [129.] ,	 min:  [90.]
# Formula phi2:	 [1.] , 	max:  [129.] ,	 min:  [90.]
#
# Formula phi1:	 [-10.] , 	max:  [150.] ,	 min:  [74.]
# Formula phi2:	 [-8.] , 	max:  [150.] ,	 min:  [74.]
#
# Formula phi1:	 [0.] , 	max:  [140.] ,	 min:  [88.]
# Formula phi2:	 [4.] , 	max:  [140.] ,	 min:  [88.]
#
# Formula phi1:	 [-9.] , 	max:  [123.] ,	 min:  [79.]
# Formula phi2:	 [-6.] , 	max:  [123.] ,	 min:  [79.]
#
# Formula phi1:	 [-15.] , 	max:  [155.] ,	 min:  [74.]
# Formula phi2:	 [-12.] , 	max:  [155.] ,	 min:  [74.]
#
# Formula phi1:	 [-7.] , 	max:  [147.] ,	 min:  [76.]
# Formula phi2:	 [1.] , 	max:  [147.] ,	 min:  [76.]
#
# Formula phi1:	 [-8.] , 	max:  [115.] ,	 min:  [90.]
# Formula phi2:	 [-4.] , 	max:  [115.] ,	 min:  [90.]
#
# Formula phi1:	 [-18.] , 	max:  [142.] ,	 min:  [75.]
# Formula phi2:	 [-15.] , 	max:  [142.] ,	 min:  [75.]
#
# Formula phi1:	 [2.] , 	max:  [133.] ,	 min:  [75.]
# Formula phi2:	 [8.] , 	max:  [133.] ,	 min:  [75.]
#
# Formula phi1:	 [-1.] , 	max:  [131.] ,	 min:  [82.]
# Formula phi2:	 [3.] , 	max:  [131.] ,	 min:  [82.]
#
# Formula phi1:	 [-8.] , 	max:  [148.] ,	 min:  [84.]
# Formula phi2:	 [-6.] , 	max:  [148.] ,	 min:  [84.]
#
# Formula phi1:	 [-12.] , 	max:  [132.] ,	 min:  [75.]
# Formula phi2:	 [-7.] , 	max:  [132.] ,	 min:  [75.]
#
# Formula phi1:	 [-6.] , 	max:  [141.] ,	 min:  [78.]
# Formula phi2:	 [-1.] , 	max:  [141.] ,	 min:  [78.]
#
# Formula phi1:	 [-7.] , 	max:  [125.] ,	 min:  [59.]
# Formula phi2:	 [-4.] , 	max:  [125.] ,	 min:  [59.]
#
# Formula phi1:	 [-8.] , 	max:  [131.] ,	 min:  [86.]
# Formula phi2:	 [-5.] , 	max:  [131.] ,	 min:  [86.]
#
# Formula phi1:	 [-16.] , 	max:  [113.] ,	 min:  [68.]
# Formula phi2:	 [-13.] , 	max:  [113.] ,	 min:  [68.]
#
# Formula phi1:	 [-8.] , 	max:  [122.] ,	 min:  [74.]
# Formula phi2:	 [-5.] , 	max:  [122.] ,	 min:  [74.]
#
# Formula phi1:	 [-19.] , 	max:  [124.] ,	 min:  [73.]
# Formula phi2:	 [-14.] , 	max:  [124.] ,	 min:  [73.]
#
# Formula phi1:	 [-10.] , 	max:  [129.] ,	 min:  [68.]
# Formula phi2:	 [-7.] , 	max:  [129.] ,	 min:  [68.]
#
# Formula phi1:	 [7.] , 	max:  [128.] ,	 min:  [80.]
# Formula phi2:	 [10.] , 	max:  [128.] ,	 min:  [80.]
#
# Formula phi1:	 [-12.] , 	max:  [129.] ,	 min:  [73.]
# Formula phi2:	 [-9.] , 	max:  [129.] ,	 min:  [73.]
#
# Formula phi1:	 [4.] , 	max:  [134.] ,	 min:  [74.]
# Formula phi2:	 [7.] , 	max:  [134.] ,	 min:  [74.]
#
# Formula phi1:	 [-17.] , 	max:  [117.] ,	 min:  [68.]
# Formula phi2:	 [-14.] , 	max:  [117.] ,	 min:  [68.]
#
# Formula phi1:	 [-15.] , 	max:  [116.] ,	 min:  [84.]
# Formula phi2:	 [-12.] , 	max:  [116.] ,	 min:  [84.]
#
# Formula phi1:	 [-26.] , 	max:  [116.] ,	 min:  [64.]
# Formula phi2:	 [-24.] , 	max:  [116.] ,	 min:  [64.]
#
# Formula phi1:	 [-18.] , 	max:  [122.] ,	 min:  [70.]
# Formula phi2:	 [-15.] , 	max:  [122.] ,	 min:  [70.]
#
# Formula phi1:	 [-9.] , 	max:  [115.] ,	 min:  [74.]
# Formula phi2:	 [-4.] , 	max:  [115.] ,	 min:  [74.]
#
# Formula phi1:	 [-26.] , 	max:  [123.] ,	 min:  [62.]
# Formula phi2:	 [-22.] , 	max:  [123.] ,	 min:  [62.]
#
# Formula phi1:	 [-33.] , 	max:  [102.] ,	 min:  [56.]
# Formula phi2:	 [-30.] , 	max:  [102.] ,	 min:  [56.]
#
# Formula phi1:	 [-4.] , 	max:  [117.] ,	 min:  [84.]
# Formula phi2:	 [-1.] , 	max:  [117.] ,	 min:  [84.]
#
# Formula phi1:	 [-20.] , 	max:  [116.] ,	 min:  [70.]
# Formula phi2:	 [-17.] , 	max:  [116.] ,	 min:  [70.]
#
# Formula phi1:	 [-28.] , 	max:  [168.] ,	 min:  [88.]
# Formula phi2:	 [-24.] , 	max:  [168.] ,	 min:  [88.]
#
# Formula phi1:	 [-18.] , 	max:  [158.] ,	 min:  [80.]
# Formula phi2:	 [-16.] , 	max:  [158.] ,	 min:  [80.]
#
# Formula phi1:	 [-19.] , 	max:  [159.] ,	 min:  [82.]
# Formula phi2:	 [-16.] , 	max:  [159.] ,	 min:  [82.]
#
# Formula phi1:	 [-4.] , 	max:  [144.] ,	 min:  [85.]
# Formula phi2:	 [-1.] , 	max:  [144.] ,	 min:  [85.]
#
# Formula phi1:	 [-18.] , 	max:  [142.] ,	 min:  [79.]
# Formula phi2:	 [-18.] , 	max:  [142.] ,	 min:  [79.]
#
# Formula phi1:	 [-14.] , 	max:  [154.] ,	 min:  [88.]
# Formula phi2:	 [-11.] , 	max:  [154.] ,	 min:  [88.]
#
# Formula phi1:	 [-7.] , 	max:  [138.] ,	 min:  [90.]
# Formula phi2:	 [-4.] , 	max:  [138.] ,	 min:  [90.]
#
# Formula phi1:	 [-18.] , 	max:  [158.] ,	 min:  [88.]
# Formula phi2:	 [-15.] , 	max:  [158.] ,	 min:  [88.]
#
# Formula phi1:	 [-6.] , 	max:  [143.] ,	 min:  [94.]
# Formula phi2:	 [-2.] , 	max:  [143.] ,	 min:  [94.]
#
# Formula phi1:	 [-3.] , 	max:  [143.] ,	 min:  [87.]
# Formula phi2:	 [0.] , 	max:  [143.] ,	 min:  [87.]
#
# Formula phi1:	 [-7.] , 	max:  [147.] ,	 min:  [73.]
# Formula phi2:	 [-4.] , 	max:  [147.] ,	 min:  [73.]
#
# Formula phi1:	 [-12.] , 	max:  [140.] ,	 min:  [79.]
# Formula phi2:	 [-8.] , 	max:  [140.] ,	 min:  [79.]
#
# Formula phi1:	 [-19.] , 	max:  [125.] ,	 min:  [70.]
# Formula phi2:	 [-17.] , 	max:  [125.] ,	 min:  [70.]
#
# Formula phi1:	 [1.] , 	max:  [139.] ,	 min:  [75.]
# Formula phi2:	 [4.] , 	max:  [139.] ,	 min:  [75.]
#
# Formula phi1:	 [-19.] , 	max:  [139.] ,	 min:  [67.]
# Formula phi2:	 [-14.] , 	max:  [139.] ,	 min:  [67.]
#
# Formula phi1:	 [-21.] , 	max:  [131.] ,	 min:  [79.]
# Formula phi2:	 [-19.] , 	max:  [131.] ,	 min:  [79.]
#
# Formula phi1:	 [-2.] , 	max:  [135.] ,	 min:  [89.]
# Formula phi2:	 [1.] , 	max:  [135.] ,	 min:  [89.]
#
# Formula phi1:	 [-6.] , 	max:  [133.] ,	 min:  [74.]
# Formula phi2:	 [-2.] , 	max:  [133.] ,	 min:  [74.]
#
# Formula phi1:	 [-6.] , 	max:  [136.] ,	 min:  [83.]
# Formula phi2:	 [-2.] , 	max:  [136.] ,	 min:  [83.]
#
# Formula phi1:	 [-16.] , 	max:  [130.] ,	 min:  [82.]
# Formula phi2:	 [-10.] , 	max:  [130.] ,	 min:  [82.]
#
# Formula phi1:	 [-10.] , 	max:  [127.] ,	 min:  [82.]
# Formula phi2:	 [-7.] , 	max:  [127.] ,	 min:  [82.]
#
# Formula phi1:	 [-10.] , 	max:  [133.] ,	 min:  [75.]
# Formula phi2:	 [-4.] , 	max:  [133.] ,	 min:  [75.]
#
# Formula phi1:	 [-14.] , 	max:  [113.] ,	 min:  [63.]
# Formula phi2:	 [-11.] , 	max:  [113.] ,	 min:  [63.]
#
# Formula phi1:	 [-1.] , 	max:  [127.] ,	 min:  [78.]
# Formula phi2:	 [3.] , 	max:  [127.] ,	 min:  [78.]
#
# Formula phi1:	 [-12.] , 	max:  [116.] ,	 min:  [77.]
# Formula phi2:	 [-10.] , 	max:  [116.] ,	 min:  [77.]
#
# Formula phi1:	 [1.] , 	max:  [130.] ,	 min:  [81.]
# Formula phi2:	 [5.] , 	max:  [130.] ,	 min:  [81.]
#
# Formula phi1:	 [-10.] , 	max:  [129.] ,	 min:  [85.]
# Formula phi2:	 [-6.] , 	max:  [129.] ,	 min:  [85.]
#
# Formula phi1:	 [-18.] , 	max:  [118.] ,	 min:  [71.]
# Formula phi2:	 [-15.] , 	max:  [118.] ,	 min:  [71.]
#
# Formula phi1:	 [-4.] , 	max:  [122.] ,	 min:  [79.]
# Formula phi2:	 [-2.] , 	max:  [122.] ,	 min:  [79.]
#
# Formula phi1:	 [-5.] , 	max:  [124.] ,	 min:  [84.]
# Formula phi2:	 [-2.] , 	max:  [124.] ,	 min:  [84.]
#
# Formula phi1:	 [-6.] , 	max:  [135.] ,	 min:  [76.]
# Formula phi2:	 [-4.] , 	max:  [135.] ,	 min:  [76.]
#
# Formula phi1:	 [-9.] , 	max:  [123.] ,	 min:  [76.]
# Formula phi2:	 [-5.] , 	max:  [123.] ,	 min:  [76.]
#
# Formula phi1:	 [-10.] , 	max:  [117.] ,	 min:  [70.]
# Formula phi2:	 [-6.] , 	max:  [117.] ,	 min:  [70.]
#
# Formula phi1:	 [-6.] , 	max:  [143.] ,	 min:  [92.]
# Formula phi2:	 [-3.] , 	max:  [143.] ,	 min:  [92.]
#
# Formula phi1:	 [-17.] , 	max:  [133.] ,	 min:  [83.]
# Formula phi2:	 [-14.] , 	max:  [133.] ,	 min:  [83.]
#
# Formula phi1:	 [-19.] , 	max:  [122.] ,	 min:  [67.]
# Formula phi2:	 [-16.] , 	max:  [122.] ,	 min:  [67.]
#
# Formula phi1:	 [0.] , 	max:  [130.] ,	 min:  [78.]
# Formula phi2:	 [3.] , 	max:  [130.] ,	 min:  [78.]
#
# Formula phi1:	 [-22.] , 	max:  [114.] ,	 min:  [74.]
# Formula phi2:	 [-20.] , 	max:  [114.] ,	 min:  [74.]
#
# Formula phi1:	 [-15.] , 	max:  [126.] ,	 min:  [70.]
# Formula phi2:	 [-12.] , 	max:  [126.] ,	 min:  [70.]
#
# Formula phi1:	 [-13.] , 	max:  [132.] ,	 min:  [72.]
# Formula phi2:	 [-9.] , 	max:  [132.] ,	 min:  [72.]
#
# Formula phi1:	 [-17.] , 	max:  [157.] ,	 min:  [84.]
# Formula phi2:	 [-13.] , 	max:  [157.] ,	 min:  [84.]
#
# Formula phi1:	 [-29.] , 	max:  [169.] ,	 min:  [74.]
# Formula phi2:	 [-26.] , 	max:  [169.] ,	 min:  [74.]
#
# Formula phi1:	 [-25.] , 	max:  [165.] ,	 min:  [77.]
# Formula phi2:	 [-22.] , 	max:  [165.] ,	 min:  [77.]
#
# Formula phi1:	 [-20.] , 	max:  [160.] ,	 min:  [85.]
# Formula phi2:	 [-18.] , 	max:  [160.] ,	 min:  [85.]
#
# Formula phi1:	 [-6.] , 	max:  [146.] ,	 min:  [88.]
# Formula phi2:	 [-3.] , 	max:  [146.] ,	 min:  [88.]
#
# Formula phi1:	 [-21.] , 	max:  [161.] ,	 min:  [90.]
# Formula phi2:	 [-18.] , 	max:  [161.] ,	 min:  [90.]
#
# Formula phi1:	 [-17.] , 	max:  [157.] ,	 min:  [90.]
# Formula phi2:	 [-14.] , 	max:  [157.] ,	 min:  [90.]
#
# Formula phi1:	 [-21.] , 	max:  [161.] ,	 min:  [97.]
# Formula phi2:	 [-18.] , 	max:  [161.] ,	 min:  [97.]
#
# Formula phi1:	 [-11.] , 	max:  [151.] ,	 min:  [92.]
# Formula phi2:	 [-8.] , 	max:  [151.] ,	 min:  [92.]
#
# Formula phi1:	 [0.] , 	max:  [138.] ,	 min:  [76.]
# Formula phi2:	 [2.] , 	max:  [138.] ,	 min:  [76.]
#
# Formula phi1:	 [1.] , 	max:  [138.] ,	 min:  [80.]
# Formula phi2:	 [3.] , 	max:  [138.] ,	 min:  [80.]
#
# Formula phi1:	 [-33.] , 	max:  [173.] ,	 min:  [75.]
# Formula phi2:	 [-30.] , 	max:  [173.] ,	 min:  [75.]
#
# Formula phi1:	 [-5.] , 	max:  [140.] ,	 min:  [75.]
# Formula phi2:	 [0.] , 	max:  [140.] ,	 min:  [75.]
#
# Formula phi1:	 [-7.] , 	max:  [147.] ,	 min:  [94.]
# Formula phi2:	 [-4.] , 	max:  [147.] ,	 min:  [94.]
#
# Formula phi1:	 [-18.] , 	max:  [158.] ,	 min:  [73.]
# Formula phi2:	 [-13.] , 	max:  [158.] ,	 min:  [73.]
#
# Formula phi1:	 [-9.] , 	max:  [149.] ,	 min:  [76.]
# Formula phi2:	 [-5.] , 	max:  [149.] ,	 min:  [76.]
#
# Formula phi1:	 [0.] , 	max:  [139.] ,	 min:  [74.]
# Formula phi2:	 [4.] , 	max:  [139.] ,	 min:  [74.]
#
# Formula phi1:	 [-2.] , 	max:  [135.] ,	 min:  [80.]
# Formula phi2:	 [0.] , 	max:  [135.] ,	 min:  [80.]
#
# Formula phi1:	 [-7.] , 	max:  [137.] ,	 min:  [77.]
# Formula phi2:	 [-4.] , 	max:  [137.] ,	 min:  [77.]
#
# Formula phi1:	 [-2.] , 	max:  [142.] ,	 min:  [77.]
# Formula phi2:	 [1.] , 	max:  [142.] ,	 min:  [77.]
#
# Formula phi1:	 [-1.] , 	max:  [131.] ,	 min:  [78.]
# Formula phi2:	 [0.] , 	max:  [131.] ,	 min:  [78.]
#
# Formula phi1:	 [-14.] , 	max:  [154.] ,	 min:  [86.]
# Formula phi2:	 [-11.] , 	max:  [154.] ,	 min:  [86.]
#
# Formula phi1:	 [3.] , 	max:  [134.] ,	 min:  [85.]
# Formula phi2:	 [6.] , 	max:  [134.] ,	 min:  [85.]
#
# Formula phi1:	 [-12.] , 	max:  [127.] ,	 min:  [72.]
# Formula phi2:	 [-10.] , 	max:  [127.] ,	 min:  [72.]
#
# Formula phi1:	 [-11.] , 	max:  [144.] ,	 min:  [80.]
# Formula phi2:	 [-9.] , 	max:  [144.] ,	 min:  [80.]
#
# Formula phi1:	 [-12.] , 	max:  [138.] ,	 min:  [86.]
# Formula phi2:	 [-9.] , 	max:  [138.] ,	 min:  [86.]
#
# Formula phi1:	 [-8.] , 	max:  [136.] ,	 min:  [81.]
# Formula phi2:	 [-4.] , 	max:  [136.] ,	 min:  [81.]
#
# Formula phi1:	 [1.] , 	max:  [135.] ,	 min:  [77.]
# Formula phi2:	 [5.] , 	max:  [135.] ,	 min:  [77.]
#
# Formula phi1:	 [-2.] , 	max:  [142.] ,	 min:  [91.]
# Formula phi2:	 [1.] , 	max:  [142.] ,	 min:  [91.]
#
# Formula phi1:	 [-22.] , 	max:  [149.] ,	 min:  [75.]
# Formula phi2:	 [-18.] , 	max:  [149.] ,	 min:  [75.]
#
# Formula phi1:	 [-6.] , 	max:  [126.] ,	 min:  [89.]
# Formula phi2:	 [-3.] , 	max:  [126.] ,	 min:  [89.]
#
# Formula phi1:	 [-10.] , 	max:  [141.] ,	 min:  [82.]
# Formula phi2:	 [-6.] , 	max:  [141.] ,	 min:  [82.]
#
# Formula phi1:	 [-18.] , 	max:  [122.] ,	 min:  [75.]
# Formula phi2:	 [-15.] , 	max:  [122.] ,	 min:  [75.]
#
# Formula phi1:	 [-22.] , 	max:  [123.] ,	 min:  [62.]
# Formula phi2:	 [-18.] , 	max:  [123.] ,	 min:  [62.]
#
# Formula phi1:	 [-15.] , 	max:  [137.] ,	 min:  [80.]
# Formula phi2:	 [-12.] , 	max:  [137.] ,	 min:  [80.]
#
# Formula phi1:	 [-3.] , 	max:  [125.] ,	 min:  [85.]
# Formula phi2:	 [0.] , 	max:  [125.] ,	 min:  [85.]
#
# Formula phi1:	 [-17.] , 	max:  [125.] ,	 min:  [71.]
# Formula phi2:	 [-13.] , 	max:  [125.] ,	 min:  [71.]
#
# Formula phi1:	 [-20.] , 	max:  [119.] ,	 min:  [66.]
# Formula phi2:	 [-17.] , 	max:  [119.] ,	 min:  [66.]
#
# Formula phi1:	 [-26.] , 	max:  [119.] ,	 min:  [74.]
# Formula phi2:	 [-22.] , 	max:  [119.] ,	 min:  [74.]
#
# Formula phi1:	 [-18.] , 	max:  [123.] ,	 min:  [70.]
# Formula phi2:	 [-16.] , 	max:  [123.] ,	 min:  [70.]
# The maximum value is  -3.5  for the couple [ 18 ,  0.13 ]
# The maximum value is  -0.125  for the couple [ 18 ,  0.13 ]
